# %% [markdown]
# # Crawling Twitter Data Using `tweet-harvest'

# %% [markdown]
# ## Crawling Tweet

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [49.8 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,278 kB]
# ...

# %%
# Crawl Data

filename = 'pilpres.csv'
search_keyword = 'pilpres (from:detikcom) lang:id until:2023-11-13 since:2023-05-12'
limit = 1500

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token ""
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                          created_at               id_str  \
# 0    Sun Nov 12 14:25:00 +0000 2023  1723708475874623646
# 1    Sun Nov 12 12:55:00 +0000 2023  1723685826473992270
# 2    Sun Nov 12 09:50:00 +0000 2023  1723639269699256374
# 3    Sun Nov 12 08:35:00 +0000 2023  1723620395352281493
# 4    Sun Nov 12 07:45:00 +0000 2023  1723607812406649152
# ..                              ...                  ...
# 609  Sat May 13 09:15:00 +0000 2023  1657313482289606661
# 610  Fri May 12 15:50:00 +0000 2023  1657050499508584450
# 611  Fri May 12 13:40:00 +0000 2023  1657017784012795911
# 612  Fri May 12 08:20:00 +0000 2023  1656937253137170433
# 613  Fri May 12 02:50:00 +0000 2023  1656854205888610304
#
#                                              full_text  quote_count  \
# 0    Anies Yakin Menang Satu Putaran, Sandiaga Pred...            4
# 1    Gibran Optimistis Menang Satu Putaran di Pilpr...           15
# 2    Anies Yakin Menang Pilpres Satu Putaran  Anies...           58
# ...

# %%
# merged
df1=pd.read_csv('/content/tweets-data/pilpres_kompastv_test.csv', delimiter=";")
df2=pd.read_csv('/content/tweets-data/pilpres_kompastv_test_2.csv', delimiter=';')
df3=pd.read_csv('/content/tweets-data/pilpres_merdekadotcom_test.csv', delimiter=';')
df4=pd.read_csv('/content/tweets-data/pilpres_metrotv_test.csv', delimiter=';')

# merge
merged_df=pd.concat([df1, df2, df3, df4], ignore_index=True)
merged_df
# Out:
#                           created_at               id_str  \
# 0     Sun Nov 12 20:54:33 +0000 2023  1723806511233957918
# 1     Sun Nov 12 17:58:10 +0000 2023  1723762122482761942
# 2     Sun Nov 12 15:55:05 +0000 2023  1723731145723154855
# 3     Sun Nov 12 15:01:05 +0000 2023  1723717556224348332
# 4     Sun Nov 12 13:53:13 +0000 2023  1723700478167679426
# ...                              ...                  ...
# 1429  Thu May 25 16:00:38 +0000 2023  1661764217547149313
# 1430  Tue May 16 08:51:38 +0000 2023  1658394764772007937
# 1431  Tue May 16 08:48:20 +0000 2023  1658393934274662401
# 1432  Tue May 16 04:57:15 +0000 2023  1658335783173095424
# 1433  Sun May 14 07:34:25 +0000 2023  1657650560282296320
#
#                                               full_text  quote_count  \
# 0     Jelang Pilpres 2024, Situasi Politik Indonesia...            1
# 1     Soal Pemasangan Baliho, PKB Kritik Netralitas ...            1
# ...

# %%
# merged_df.to_excel('Tweets Training 2.xlsx', index=False)

# %% [markdown]
# ## Crawling Reply

# %%
#@title Twitter Auth Token

twitter_auth_token = '3cb9f1108dc4efa7b7c7d83d4b9e72a808dc93c3'

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...

# %%
# Crawl Data

filename = 'reply.csv'
twitter_thread_url = 'https://twitter.com/detikcom/status/1723708475874623646'
limit = 1500

# !npx --yes tweet-harvest@latest -o {filename} -l {limit} --token {twitter_auth_token} --thread {twitter_thread_url}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# up to date, audited 4 packages in 1s
#
# found 0 vulnerabilities
# Installing dependencies...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# ...

# %% [markdown]
# ### read

# %%
import pandas as pd
df=pd.read_csv('/content/tweets-data/reply.csv', delimiter=';')
df
# Out:
#                        created_at               id_str  \
# 0  Sun Nov 12 14:36:18 +0000 2023  1723711318765818202
# 1  Sun Nov 12 16:50:10 +0000 2023  1723745010880073847
#
#                                            full_text  quote_count  \
# 0  Wajar memiliki pandangan berbeda, semoga pemil...            0
# 1     G punya pendirian ini orang,,numpang kekuasaan            0
#
#    reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0            0              0               0   in             89169305
# 1            0              0               1   in  1304132864183738369
#
#    conversation_id_str       username  \
# 0  1723708475874623646   dAsalbantani
# 1  1723708475874623646  IyusPriandani
#
#                                            tweet_url
# 0  https://twitter.com/dAsalbantani/status/172371...
# 1  https://twitter.com/IyusPriandani/status/17237...

# %% [markdown]
# ### read data test reply detikcom

# %%
import pandas as pd
#df genap
df2=pd.read_csv('/content/tweets-data/reply_2.csv', delimiter=";")
df4=pd.read_csv('/content/tweets-data/reply_4.csv', delimiter=";")
df6=pd.read_csv('/content/tweets-data/reply_6.csv', delimiter=";")
df8=pd.read_csv('/content/tweets-data/reply_8.csv', delimiter=";")
df10=pd.read_csv('/content/tweets-data/reply_10.csv', delimiter=";")
df12=pd.read_csv('/content/tweets-data/reply_12.csv', delimiter=";")
df14=pd.read_csv('/content/tweets-data/reply_14.csv', delimiter=";")
df16=pd.read_csv('/content/tweets-data/reply_16.csv', delimiter=";")
df18=pd.read_csv('/content/tweets-data/reply_18.csv', delimiter=";")
df20=pd.read_csv('/content/tweets-data/reply_20.csv', delimiter=";")
df22=pd.read_csv('/content/tweets-data/reply_22.csv', delimiter=";")
df24=pd.read_csv('/content/tweets-data/reply_24.csv', delimiter=";")
df26=pd.read_csv('/content/tweets-data/reply_266.csv', delimiter=";")
df28=pd.read_csv('/content/tweets-data/reply_28.csv', delimiter=";")
df30=pd.read_csv('/content/tweets-data/reply_30.csv', delimiter=";")
df32=pd.read_csv('/content/tweets-data/reply_32.csv', delimiter=";")
df34=pd.read_csv('/content/tweets-data/reply_34.csv', delimiter=";")
df36=pd.read_csv('/content/tweets-data/reply_36.csv', delimiter=";")
df38=pd.read_csv('/content/tweets-data/reply_38.csv', delimiter=";")
df40=pd.read_csv('/content/tweets-data/reply_40.csv', delimiter=";")
df42=pd.read_csv('/content/tweets-data/reply_42.csv', delimiter=";")
df44=pd.read_csv('/content/tweets-data/reply_44.csv', delimiter=";")
df46=pd.read_csv('/content/tweets-data/reply_46.csv', delimiter=";")
df48=pd.read_csv('/content/tweets-data/reply_48.csv', delimiter=";")
df50=pd.read_csv('/content/tweets-data/reply_50.csv', delimiter=";")
df52=pd.read_csv('/content/tweets-data/reply_52.csv', delimiter=";")
df54=pd.read_csv('/content/tweets-data/reply_54.csv', delimiter=";")
df56=pd.read_csv('/content/tweets-data/reply_56.csv', delimiter=";")
df58=pd.read_csv('/content/tweets-data/reply_58.csv', delimiter=";")
df60=pd.read_csv('/content/tweets-data/reply_60.csv', delimiter=";")
df62=pd.read_csv('/content/tweets-data/reply_62.csv', delimiter=";")
df64=pd.read_csv('/content/tweets-data/reply_64.csv', delimiter=";")
df66=pd.read_csv('/content/tweets-data/reply_66.csv', delimiter=";")
df68=pd.read_csv('/content/tweets-data/reply_68.csv', delimiter=";")
df70=pd.read_csv('/content/tweets-data/reply_70.csv', delimiter=";")
df72=pd.read_csv('/content/tweets-data/reply_72.csv', delimiter=";")
df74=pd.read_csv('/content/tweets-data/reply_74.csv', delimiter=";")
df76=pd.read_csv('/content/tweets-data/reply_76.csv', delimiter=";")
df78=pd.read_csv('/content/tweets-data/reply_78.csv', delimiter=";")
df80=pd.read_csv('/content/tweets-data/reply_80.csv', delimiter=";")
df82=pd.read_csv('/content/tweets-data/reply_82.csv', delimiter=";")
df84=pd.read_csv('/content/tweets-data/reply_84.csv', delimiter=";")
df86=pd.read_csv('/content/tweets-data/reply_86.csv', delimiter=";")
df88=pd.read_csv('/content/tweets-data/reply_88.csv', delimiter=";")
df90=pd.read_csv('/content/tweets-data/reply_90.csv', delimiter=";")
df92=pd.read_csv('/content/tweets-data/reply_92.csv', delimiter=";")
df94=pd.read_csv('/content/tweets-data/reply_94.csv', delimiter=";")
df96=pd.read_csv('/content/tweets-data/reply_96.csv', delimiter=";")
df98=pd.read_csv('/content/tweets-data/reply_98.csv', delimiter=";")
df100=pd.read_csv('/content/tweets-data/reply_100.csv', delimiter=";")

# %% [markdown]
# ### read data train reply kompastv

# %%
import pandas as pd
df2=pd.read_csv('/content/tweets-data/reply_kompastv_2.csv', delimiter=';')
df4=pd.read_csv('/content/tweets-data/reply_kompastv_4.csv', delimiter=';')
df6=pd.read_csv('/content/tweets-data/reply_kompastv_6.csv', delimiter=';')
df8=pd.read_csv('/content/tweets-data/reply_kompastv_8.csv', delimiter=';')
df10=pd.read_csv('/content/tweets-data/reply_kompastv_10.csv', delimiter=';')
df12=pd.read_csv('/content/tweets-data/reply_kompastv_12.csv', delimiter=';')
df14=pd.read_csv('/content/tweets-data/reply_kompastv_14.csv', delimiter=';')
df16=pd.read_csv('/content/tweets-data/reply_kompastv_16.csv', delimiter=';')
df18=pd.read_csv('/content/tweets-data/reply_kompastv_18.csv', delimiter=';')
df20=pd.read_csv('/content/tweets-data/reply_kompastv_20.csv', delimiter=';')
df22=pd.read_csv('/content/tweets-data/reply_kompastv_22.csv', delimiter=';')
df24=pd.read_csv('/content/tweets-data/reply_kompastv_24.csv', delimiter=';')
df26=pd.read_csv('/content/tweets-data/reply_kompastv_26.csv', delimiter=';')
df28=pd.read_csv('/content/tweets-data/reply_kompastv_28.csv', delimiter=';')
df30=pd.read_csv('/content/tweets-data/reply_kompastv_30.csv', delimiter=';')
df32=pd.read_csv('/content/tweets-data/reply_kompastv_32.csv', delimiter=';')
df34=pd.read_csv('/content/tweets-data/reply_kompastv_34.csv', delimiter=';')
df36=pd.read_csv('/content/tweets-data/reply_kompastv_36.csv', delimiter=';')
df38=pd.read_csv('/content/tweets-data/reply_kompastv_38.csv', delimiter=';')
df40=pd.read_csv('/content/tweets-data/reply_kompastv_40.csv', delimiter=';')
df42=pd.read_csv('/content/tweets-data/reply_kompastv_42.csv', delimiter=';')
df44=pd.read_csv('/content/tweets-data/reply_kompastv_44.csv', delimiter=';')
df46=pd.read_csv('/content/tweets-data/reply_kompastv_46.csv', delimiter=';')
df48=pd.read_csv('/content/tweets-data/reply_kompastv_48.csv', delimiter=';')
df50=pd.read_csv('/content/tweets-data/reply_kompastv_50.csv', delimiter=';')

# %% [markdown]
# ### read data train reply liputan6

# %%
df1=pd.read_csv('/content/tweets-data/reply_liputan6_1.csv', delimiter=';')
df2=pd.read_csv('/content/tweets-data/reply_liputan6_2.csv', delimiter=';')
df3=pd.read_csv('/content/tweets-data/reply_liputan6_3.csv', delimiter=';')
df4=pd.read_csv('/content/tweets-data/reply_liputan6_4.csv', delimiter=';')
df5=pd.read_csv('/content/tweets-data/reply_liputan6_5.csv', delimiter=';')
df6=pd.read_csv('/content/tweets-data/reply_liputan6_6.csv', delimiter=';')
df7=pd.read_csv('/content/tweets-data/reply_liputan6_7.csv', delimiter=';')
df8=pd.read_csv('/content/tweets-data/reply_liputan6_8.csv', delimiter=';')
df9=pd.read_csv('/content/tweets-data/reply_liputan6_9.csv', delimiter=';')
df10=pd.read_csv('/content/tweets-data/reply_liputan6_10.csv', delimiter=';')
df11=pd.read_csv('/content/tweets-data/reply_liputan6_11.csv', delimiter=';')
df12=pd.read_csv('/content/tweets-data/reply_liputan6_12.csv', delimiter=';')

# %% [markdown]
# ### read data train reply merdekadotcom

# %%
df_merdekadotcom=pd.read_csv('/content/tweets-data/reply_merdekadotcom.csv', delimiter=';')
df_merdekadotcom
# Out:
#                        created_at               id_str  \
# 0  Sun May 21 15:53:34 +0000 2023  1660312890338062336
# 1  Sun May 21 10:32:43 +0000 2023  1660232142578913281
# 2  Sun May 21 10:13:33 +0000 2023  1660227321637507073
# 3  Sun May 21 23:30:51 +0000 2023  1660427968253132800
# 4  Sun May 21 10:16:06 +0000 2023  1660227963173093376
# 5  Sun May 21 10:43:39 +0000 2023  1660234896223379457
# 6  Sun May 21 20:16:21 +0000 2023  1660379019748188160
# 7  Sun May 21 11:31:39 +0000 2023  1660246975894421504
#
#                                            full_text  quote_count  \
# 0  Selama sesuai yg dipersyaratkan konstitusi dan...            0
# 1  Maksud antum, walupun tdk diusung oleh partai ...            0
# 2  😂😂😂...ngk ada yg larang loe ikutan pilpres cuk...            0
# 3  Ini capres belum apa2 udah ngawur😟semua nya pe...            0
# 4                                          Cari muka            0
# 5   Yang larang itu pengurus parpol tersangkut korup            0
# ...

# %% [markdown]
# ### read data train reply tvone

# %%
df2=pd.read_csv('/content/tweets-data/reply_tvone_2.csv', delimiter=';')
df4=pd.read_csv('/content/tweets-data/reply_tvone_4.csv', delimiter=';')
df6=pd.read_csv('/content/tweets-data/reply_tvone_6.csv', delimiter=';')
df8=pd.read_csv('/content/tweets-data/reply_tvone_8.csv', delimiter=';')
df10=pd.read_csv('/content/tweets-data/reply_tvone_10.csv', delimiter=';')
df12=pd.read_csv('/content/tweets-data/reply_tvone_12.csv', delimiter=';')
df14=pd.read_csv('/content/tweets-data/reply_tvone_14.csv', delimiter=';')
df16=pd.read_csv('/content/tweets-data/reply_tvone_16.csv', delimiter=';')
df18=pd.read_csv('/content/tweets-data/reply_tvone_18.csv', delimiter=';')
df20=pd.read_csv('/content/tweets-data/reply_tvone_20.csv', delimiter=';')

# %% [markdown]
# ### read data train reply tribunnews

# %%
df2=pd.read_csv('/content/tweets-data/reply_tribunnews_2.csv', delimiter=';')
df4=pd.read_csv('/content/tweets-data/reply_tribunnews_4.csv', delimiter=';')
df6=pd.read_csv('/content/tweets-data/reply_tribunnews_6.csv', delimiter=';')
df8=pd.read_csv('/content/tweets-data/reply_tribunnews_8.csv', delimiter=';')
df10=pd.read_csv('/content/tweets-data/reply_tribunnews_10.csv', delimiter=';')
df12=pd.read_csv('/content/tweets-data/reply_tribunnews_12.csv', delimiter=';')
df13=pd.read_csv('/content/tweets-data/reply_tribunnews_13.csv', delimiter=';')
df14=pd.read_csv('/content/tweets-data/reply_tribunnews_14.csv', delimiter=';')
df15=pd.read_csv('/content/tweets-data/reply_tribunnews_15.csv', delimiter=';')

# %% [markdown]
# ### merge

# %% [markdown]
# ### merge data test reply detikcom

# %%
# merge
merged_df=pd.concat([df2, df4, df6, df8, df10,
                     df12, df14, df16, df18, df20,
                     df22, df24, df26, df28, df30,
                     df32, df34, df36, df38, df40,
                     df42, df44, df46, df48, df50,
                     df52, df54, df56, df58, df60,
                     df62, df64, df66, df68, df70,
                     df72, df74, df76, df78, df80,
                     df82, df84, df86, df88, df90,
                     df92, df94, df96, df98, df100], ignore_index=True)
merged_df
# Out:
#                           created_at               id_str  \
# 0     Sun Sep 10 14:19:49 +0000 2023  1700876736966410502
# 1     Mon Sep 11 01:47:35 +0000 2023  1701049817550729411
# 2     Mon Sep 11 01:55:22 +0000 2023  1701051777817489507
# 3     Sun Sep 10 15:43:50 +0000 2023  1700897881681694940
# 4     Sun Sep 10 15:19:55 +0000 2023  1700891860678701339
# ...                              ...                  ...
# 1588  Tue Sep 19 12:49:05 +0000 2023  1704115392954982828
# 1589  Mon Sep 18 10:03:19 +0000 2023  1703711288143265870
# 1590  Mon Sep 18 07:44:18 +0000 2023  1703676306234470638
# 1591  Tue Sep 19 00:48:02 +0000 2023  1703933934340546863
# 1592  Mon Sep 18 08:03:22 +0000 2023  1703681103238996378
#
#                                               full_text  quote_count  \
# 0     Nah kalo menaikkan dana desa keren ini 👍slogan...            0
# 1           1. BBM gratis 2. Dana Desa 2M jadi 5M 3. 4.            1
# ...

# %% [markdown]
# ### merge data train reply kompastv

# %%
# merge
merged_df=pd.concat([df2, df4, df6, df8, df10,
                     df12, df14, df16, df18, df20,
                     df22, df24, df26, df28, df30,
                     df32, df34, df36, df38, df40,
                     df42, df44, df46, df48, df50], ignore_index=True)
merged_df
# Out:
#                           created_at               id_str  \
# 0     Mon Sep 04 02:39:34 +0000 2023  1698526186425491835
# 1     Mon Sep 04 13:05:43 +0000 2023  1698683761582637467
# 2     Mon Sep 04 02:43:57 +0000 2023  1698527289280213071
# 3     Mon Sep 04 05:09:25 +0000 2023  1698563898046394546
# 4     Mon Sep 04 00:58:10 +0000 2023  1698500669156524265
# ...                              ...                  ...
# 3119  Sun Jul 16 02:26:53 +0000 2023  1680403601834000384
# 3120  Sun Jul 16 10:27:28 +0000 2023  1680524544233144321
# 3121  Sun Jul 16 10:49:20 +0000 2023  1680530044974710784
# 3122  Mon Jul 17 13:22:43 +0000 2023  1680931034681180160
# 3123  Sat Jul 15 21:31:02 +0000 2023  1680329148378791936
#
#                                               full_text  quote_count  \
# 0                 KOMPAS ~ segera kalibrasi ulang deh 🤭            0
# 1                                                  hmm.            0
# ...

# %% [markdown]
# ### merge data train reply liputan6

# %%
# merge
merged_df=pd.concat([df1, df2, df3, df4, df5, df6,
                     df7, df8, df9, df10, df11, df12], ignore_index=True)
merged_df
# Out:
#                          created_at               id_str  \
# 0    Thu Sep 14 11:58:05 +0000 2023  1702290620998697064
# 1    Thu Sep 14 18:47:42 +0000 2023  1702393703774691623
# 2    Fri Sep 15 04:48:01 +0000 2023  1702544778666406381
# 3    Thu Sep 14 15:18:37 +0000 2023  1702341084482068703
# 4    Fri Sep 15 07:57:16 +0000 2023  1702592402543059278
# ..                              ...                  ...
# 254  Mon May 15 05:49:04 +0000 2023  1657986433272127488
# 255  Sun May 14 21:39:57 +0000 2023  1657863344190271488
# 256  Sun May 14 23:45:07 +0000 2023  1657894842826129409
# 257  Sun May 14 17:33:29 +0000 2023  1657801317363118081
# 258  Sun May 14 18:25:51 +0000 2023  1657814496428306433
#
#                                              full_text  quote_count  \
# 0                                         Haruslah...!            0
# 1                              Tpi sdh siap kalah kan?            0
# 2    Rakyat yg sdh muak dgn kondisi saat ini lebih ...            0
# ...

# %% [markdown]
# ### merge data train reply tvone

# %%
# merge
merged_df=pd.concat([df2, df4, df6, df8, df10,
                     df12, df14, df16, df18, df20], ignore_index=True)
merged_df
# Out:
#                           created_at               id_str  \
# 0     Tue Oct 24 18:14:52 +0000 2023  1716880954801992097
# 1     Mon Oct 23 22:45:20 +0000 2023  1716586633699713244
# 2     Tue Oct 24 03:42:54 +0000 2023  1716661517012152465
# 3     Wed Nov 08 01:50:33 +0000 2023  1722069063759794439
# 4     Mon Oct 23 17:37:36 +0000 2023  1716509190053855730
# ...                              ...                  ...
# 1291  Fri Nov 10 12:56:50 +0000 2023  1722961513957486891
# 1292  Fri Nov 10 11:22:39 +0000 2023  1722937809319997458
# 1293  Sat Nov 11 00:25:02 +0000 2023  1723134705095360913
# 1294  Fri Nov 10 13:47:40 +0000 2023  1722974305133224252
# 1295  Sat Nov 11 15:16:52 +0000 2023  1723359141412937858
#
#                                               full_text  quote_count  \
# 0     Kalau benar Gibran jadi Cawapres PS, waktu deb...            0
# 1                               Pemilih muda yang bloon            0
# ...

# %% [markdown]
# ### merge data train reply tribunnews

# %%
# merge
merged_df=pd.concat([df2, df4, df6, df8, df10,
                     df12, df13, df14, df15], ignore_index=True)
merged_df
# Out:
#                          created_at               id_str  \
# 0    Mon Nov 13 00:53:40 +0000 2023  1723866685697138878
# 1    Mon Nov 13 00:34:02 +0000 2023  1723861744177864982
# 2    Sun Nov 12 15:17:35 +0000 2023  1723721711923904512
# 3    Sun Nov 12 15:46:48 +0000 2023  1723729061925834858
# 4    Sun Nov 12 17:14:10 +0000 2023  1723751049654419803
# ..                              ...                  ...
# 244  Wed Oct 18 23:21:12 +0000 2023  1714783718156726361
# 245  Thu Oct 19 00:21:42 +0000 2023  1714798944751104070
# 246  Thu Oct 19 01:54:21 +0000 2023  1714822259813347667
# 247  Sat Oct 21 06:10:16 +0000 2023  1715611441892581721
# 248  Wed Oct 18 13:45:24 +0000 2023  1714638813555806291
#
#                                              full_text  quote_count  \
# 0    Kami doakan agar Anda bisa menjadi presiden In...            0
# 1                      masyarakat bersama pak ganjarrr            0
# 2                      Bersama pak Ganjar maju terusss            0
# ...

# %%
# merged_df.to_excel('Reply Train tribunnews 2.xlsx', index=False)
